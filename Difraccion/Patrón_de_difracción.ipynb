# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

# %% [markdown]
# CHEQUEAR ERRORES

# %%
gsheet = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQcUqofi-xCKjFi-WJAyEPPL8dY0Sw-R5nLMWOniF9dYRWkBtXg_QEfmhER4Btc2zYZ0bg_oYKddiNC/pub?gid=0&single=true&output=csv"
datos = pd.read_csv(gsheet,decimal='.')
x = datos["posicion (mm)"].to_numpy()
A = datos["Media"].to_numpy()
A_err = datos['error'].to_numpy()

plt.figure(figsize=(10,5))
plt.errorbar(x, A, yerr=A_err, fmt='.-', label="Datos")
plt.xlabel('Posición (mm)')
plt.ylabel('Intensidad ()')

plt.title('Patrón de difracción con rendija')
# Out:
# Text(0.5, 1.0, 'Barrido con bordes cerrados en modo 3')

# %%
xx=x[:15]
AA= A[:15]
AA_err = A_err[:15]

plt.figure(figsize=(10,5))
plt.errorbar(xx, AA, yerr=AA_err, fmt='.-', label="Datos")
plt.xlabel('Posición (mm)')
plt.ylabel('Intensidad ()')

plt.title('Barrido con bordes cerrados en modo 3')
# Out:
# Text(0.5, 1.0, 'Barrido con bordes cerrados en modo 3')
