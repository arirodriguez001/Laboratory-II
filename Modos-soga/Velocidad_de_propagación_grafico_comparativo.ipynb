# %% [markdown]
# En cada gráfico, uno para cada tanza, se compara la velocidad teórica con el promedio de las velocidades efectivas, obtenidas según los datos observados en cada modo. La vel. eff. se consigue con la frecuencia eff. y el promedio de las longitudes de onda.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Soga 1
v0, ev0= 121.9, 0.3
v1, ev1= 124.6, 3.8


plt.figure(figsize=(4,2))
plt.errorbar(x=v0, y=1, xerr=ev0, capsize=10,color='red')
plt.errorbar(x=v1, y=2, xerr=ev1, capsize=10,color='red')
plt.plot(v1,2, marker="o", color="red")

plt.title("Tanza 1")
plt.grid()
plt.ylim(0, 3)
plt.yticks([1, 2], ["Teórica","Efectiva"])
plt.xlabel("Velocidad (m/s)")
# Out:
# Text(0.5, 0, 'Velocidad (m/s)')

# %%
#Soga 2
vt2, evt2= 50.4, 0.2
v2, ev2= 50,


plt.figure(figsize=(4,2))
plt.errorbar(x=vt2, y=1, xerr=evt2, capsize=10,color='red')
plt.errorbar(x=v2, y=2, xerr=ev2, capsize=10,color='red')
plt.plot(v2,2, marker="o", color="red")

plt.title("Tanza 2")
plt.grid()
plt.ylim(0, 3)
plt.yticks([1, 2], ["Teórica","Efectiva"])
plt.xlabel("Velocidad (m/s)")

({amort:.5f} ± {damort:.5f}) s")
# Out:
# Text(0.5, 0, 'Velocidad (m/s)')

# %%
#Soga 3
vt3, evt3=
v2, ev2=


plt.figure(figsize=(4,2))
plt.errorbar(x=vt3, y=1, xerr=evt3, capsize=10,color='red')
plt.errorbar(x=v3, y=2, xerr=ev3, capsize=10,color='red')
plt.plot(v3,2, marker="o", color="red")

plt.title("Tanza 3")
plt.grid()
plt.ylim(0, 3)
plt.yticks([1, 2], ["Teórica","Efectiva"])
plt.xlabel("Velocidad (m/s)")
# Out:
# Text(0.5, 0, 'Velocidad (m/s)')
