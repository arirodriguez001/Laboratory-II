# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import pandas as pd

# %%
gsheet = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQK3kQw2oxtqk9EDzDh_VXSm6_gmrNsDuYOQ70F1TkpkNZqniWloItBrR78gevIzQutJTU80LMnr2x8/pub?gid=184491927&single=true&output=csv"
datos = pd.read_csv(gsheet,decimal='.')
t2_mix = datos['t'].to_numpy()
V2_mix = datos['V'].to_numpy()

# %%
gsheet = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRvTXBhTm7rh50c2IQuQogo1zccTyX3o4wAsjS-SBRwQfTCHe4_m48UDXPD5sk9jM4HtEQvp5XxdRLN/pub?gid=450699241&single=true&output=csv"
datos = pd.read_csv(gsheet, decimal='.')
t1_mix = datos['t (s)'].to_numpy()
V1_mix = datos['V'].to_numpy()

# %%
plt.figure()
plt.plot(t1_mix, V1_mix, label='Respuesta')
plt.plot(t2_mix, V2_mix, label='Pulso')
plt.title('Respuesta al impulso con bordes mixtos')
plt.ylabel('Voltaje (V)')
plt.xlabel('Tiempo (s)')
plt.grid(), plt.legend()
# Out:
# (None, <matplotlib.legend.Legend at 0x7a5a2d27b100>)

# %%
gsheet = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQ2WQ9PIX5aEnnjnSFGydzaiJ-T7DXPpEJA25wgpbVp96Gh-0glfQahFLeKniu4u0WLHKxyl_cb0Lmd/pub?gid=1561437108&single=true&output=csv"
datos = pd.read_csv(gsheet,decimal='.')
t2_cerr = datos['t'].to_numpy()
V2_cerr = datos['V'].to_numpy()

# %%
gsheet = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQfK1bqwyT3Sgau0abwEanAg7wgh1X_ZUGVafrODkTWp19ZpbUOzJUt5OhzJuYWUjfEbwo1aVb462d2/pub?gid=853512779&single=true&output=csv"
datos = pd.read_csv(gsheet,decimal='.')
t1_cerr = datos['t'].to_numpy()
V1_cerr = datos['V'].to_numpy()

# %%
plt.figure()
plt.plot(t1_cerr, V1_cerr, label='Respuesta')
plt.plot(t2_cerr, V2_cerr, label='Pulso')
plt.title('Respuesta al impulso con bordes cerrados')
plt.ylabel('Voltaje (V)')
plt.xlabel('Tiempo (s)')
plt.grid(), plt.legend()
# Out:
# (None, <matplotlib.legend.Legend at 0x7a5a2d1d6c20>)
