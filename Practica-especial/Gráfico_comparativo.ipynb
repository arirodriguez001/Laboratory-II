# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy
import pandas as pd
import math

# %%
plt.figure()
plt.errorbar(1.327, 1, xerr=0.012, marker="o", capsize=7.5)#Agua
plt.errorbar(1.334, 2, xerr=0.012, fmt='o', capsize=7.5)#Agua_sal_1
plt.errorbar(1.347, 3, xerr=0.018, fmt='o', capsize=7.5)#Alcohol
plt.errorbar(1.359, 4, xerr=0.004, fmt='o', capsize=7.5)#Agua_sal_2
plt.errorbar(1.458, 5, xerr=0.016, fmt='o', capsize=7.5)#Aceite
plt.errorbar(1.471, 6, xerr=0.02, fmt='o', capsize=7.5)#Acrílico
plt.yticks([1,2,3,4,5,6], ['Agua', 'Agua con 9% sal', 'Alcohol', 'Agua con 17% sal', 'Aceite', 'Acrílico'], fontsize=13)
plt.xlabel('Índice de refracción', fontsize=13)


plt.plot( 1.33,1, marker="o", color="black", label="Valores tabulados") #Agua
#plt.plot( ,2, marker="o", color="black")
plt.plot( 1.36,3, marker="o", color="black")#Alcohol
#plt.plot( ,4, marker="o", color="black")
plt.plot( 1.46,5, marker="o", color="black")#Aceite
plt.plot( 1.49,6, marker="o", color="black")#Acrílico
plt.legend()

plt.title("Índices de refracción (medidos y tabulados)", fontsize=15)
# Out:
# Text(0.5, 1.0, 'Índices de refracción (medidos y tabulados)')

# %%
plt.figure()
plt.errorbar(50, 1, xerr=2, marker="o", capsize=7.5, color="blue", label='$\Phi_c$ observado')#Agua
plt.errorbar(48.9, 1.2, xerr=0.6, marker="o", capsize=7.5, color="orange", label='$\Phi_c$ según Snell')#Agua

plt.errorbar(48, 2, xerr=2, fmt='o', capsize=7.5, color="blue")#Alcohol
plt.errorbar(47.9, 2.2, xerr=0.8, fmt='o', capsize=7.5, color="orange")#Alcohol

plt.errorbar(43, 3, xerr=2, fmt='o', capsize=7.5, color="blue")#Aceite
plt.errorbar(43.3, 3.2, xerr=0.6, fmt='o', capsize=7.5, color="orange")#Aceite

plt.errorbar(42, 4, xerr=2, fmt='o', capsize=7.5, color="blue")#Acrílico
plt.errorbar(42.8, 4.2, xerr=0.7, fmt='o', capsize=7.5, color="orange")#Aceite


plt.yticks([1.1,2.1,3.1,4.1], ['Agua', 'Alcohol', 'Aceite', 'Acrílico'], fontsize=13)
plt.xlabel('Ángulo crítico [grad]', fontsize=13)
plt.legend(), plt.title("Ángulos de reflexión total", fontsize=15)
# Out:
# (<matplotlib.legend.Legend at 0x7805b068d570>,
#  Text(0.5, 1.0, 'Ángulos de reflexión total'))
